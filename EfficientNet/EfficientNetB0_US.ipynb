# %%
import os
#US = data imbalance를 가정했을 때, RandomOverSampler 라이브러리를 활용한 image upsamling
train_dir = 'Processed_ImTr'   # Training set(preprocessed)
test_dir = 'Processed_Te'    # Test set

# %%
# 각 폴더에 있는 이미지 데이터 갯수 출력
train_class_counts = {class_name: len(os.listdir(os.path.join(train_dir, class_name))) for class_name in os.listdir(train_dir)}
test_class_counts = {class_name: len(os.listdir(os.path.join(test_dir, class_name))) for class_name in os.listdir(test_dir)}

print("Training dataset class counts:")
print(train_class_counts)

print("\nTesting dataset class counts:")
print(test_class_counts)
# Out:
# Training dataset class counts:
# {'glioma': 1020, 'meningioma': 677, 'notumor': 539, 'pituitary': 250}
#
# Testing dataset class counts:
# {'glioma': 300, 'meningioma': 306, 'notumor': 405, 'pituitary': 300}

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import cv2

# 이미지 로드 함수
def load_images_from_folder(folder, size=(224, 224)):
    images = []
    labels = []
    for class_idx, class_name in enumerate(os.listdir(folder)):
        class_folder = os.path.join(folder, class_name)
        for filename in os.listdir(class_folder):
            img = cv2.imread(os.path.join(class_folder, filename), cv2.IMREAD_GRAYSCALE)
            if img is not None:
                # efficientNetB0는 (224, 224) 크기의 입력이 필요하므로, resize 및 interpolation 적용
                img_resized = cv2.resize(img, size, interpolation=cv2.INTER_NEAREST)
                images.append(np.stack([img_resized] * 3, axis=-1))  # 3채널로 변환
                labels.append(class_idx)
    return np.array(images), np.array(labels)

# %%
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.efficientnet import preprocess_input

# 데이터 로드
X_train, y_train = load_images_from_folder(train_dir)

# training set:validation set = 8:2
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# 데이터 업샘플링
ros = RandomOverSampler(sampling_strategy='auto', random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train.reshape(X_train.shape[0], -1), y_train)

# 업샘플링된 데이터 크기 확인
print(f"Original Training set size: {X_train.shape[0]}")
print(f"Resampled Training set size: {X_train_resampled.shape[0]}")
print(f"Validation set size: {X_val.shape[0]}")

# EfficientNetB0에 입력하기 위해 데이터 전처리
X_train_resampled = preprocess_input(X_train_resampled.reshape(-1, 224, 224, 3))  # EfficientNetB0에 맞게 데이터 전처리
X_val = preprocess_input(X_val)  # 검증 데이터도 동일하게 전처리
# Out:
# Original Training set size: 1988
# Resampled Training set size: 3268
# Validation set size: 498

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam

# EfficientNetB0 기반 CNN 모델 정의
def build_model(num_classes):
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False  # False : pretrained model의 가중치 변경 없이 사용, True : 가중치 변경

    model = Sequential([
        # 특징 추출을 위환 efficientNetB0
        base_model,
        # 데이터 크기를 줄이기 위해 flatten 대신 사용
        GlobalAveragePooling2D(),
        # overfitting을 방지하기 위한 dropout
        Dropout(0.5),
        # ReLU : 은닉층에서 사용, Gradient 소실 문제 완화
        # full connected layer, 128개의 뉴런
        Dense(128, activation='relu'),
        # 4개의 클래스 분류, Softmax : 다중 클래스 분류를 위해 사용
        Dense(num_classes, activation='softmax')
    ])

    # Adam(Apaptive Moment Estimation)경사 하강법으로 가중치 업데이트, adam은 일반적으로 learning rate = 0.001을 사용
    model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    base_model.summary() # efficientNetB0 구조
    return model

# %%
model = build_model(num_classes=4) # 4개의 클래스를 분류
# Out:
# Model: "efficientnetb0"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)    │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ rescaling_6 (Rescaling)       │ (None, 224, 224, 3)       │               0 │ input_layer_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ normalization_3               │ (None, 224, 224, 3)       │               7 │ rescaling_6[0][0]          │
# ...

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_3           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
import matplotlib.pyplot as plt
import time

# %%
start = time.time() #시작 시간
history = model.fit(X_train_resampled, y_train_resampled, validation_data=(X_val, y_val), epochs=20, batch_size=32)
end = time.time() # 종료 시간

execution_time = end - start # execution time 계산
print(f"total Training time: {execution_time:.2f} seconds")
# Out:
# Epoch 1/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 49s 395ms/step - accuracy: 0.7027 - loss: 0.6816 - val_accuracy: 0.8916 - val_loss: 0.2780
# Epoch 2/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 371ms/step - accuracy: 0.8797 - loss: 0.3045 - val_accuracy: 0.8835 - val_loss: 0.2535
# Epoch 3/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 365ms/step - accuracy: 0.8946 - loss: 0.2750 - val_accuracy: 0.9036 - val_loss: 0.2365
# Epoch 4/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 371ms/step - accuracy: 0.9136 - loss: 0.2270 - val_accuracy: 0.9137 - val_loss: 0.2339
# Epoch 5/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 366ms/step - accuracy: 0.9120 - loss: 0.2185 - val_accuracy: 0.9096 - val_loss: 0.2272
# Epoch 6/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 361ms/step - accuracy: 0.9068 - loss: 0.2114 - val_accuracy: 0.8936 - val_loss: 0.2628
# Epoch 7/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 360ms/step - accuracy: 0.9196 - loss: 0.2085 - val_accuracy: 0.9337 - val_loss: 0.1749
# Epoch 8/20
# ...

# %%
# Accuracy와 Loss 그래프 출력
plt.figure(figsize=(12, 4))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score

class_labels = [class_name for class_name in os.listdir(train_dir)]

# 테스트 데이터 로드
X_test, y_test = load_images_from_folder(test_dir)

# 테스트
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 13s 282ms/step

# %%
# test 정확도 출력
test_accuracy = accuracy_score(y_test, y_pred_classes)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 82.53%

# %%
# 혼돈 행렬 출력
conf_matrix = confusion_matrix(y_test, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
